# %%
# %cd /content/drive/MyDrive/cvision/LOTR-Face-style-transfer
# Out:
# /content/drive/MyDrive/cvision/LOTR-Face-style-transfer

# %%
# !ls
# Out:
# 6.jpg		     face_detect.py  model.py		 resnet.py
# adpst		     hair.png	     modules		 test.py
# CinqueSlavery.ipynb  LICENSE	     optimizer.py	 train.py
# cropped		     logger.py	     other		 transform.py
# data		     loss.py	     prepropess_data.py
# evaluate.py	     makeup	     README.md
# face_dataset.py      makeup.py	     res

# %%
# !python test.py
# Out:
# content.jpg
# [ 0  1  2  3  4  5 10 11 12 13 14 16 17]
# orc0.jpg
# [ 0  1  3  4  5  8 10 12 13 14 16 17]
# content_seg.png
# [ 0 18]
# orc0_seg.png
# [ 0  1 18]
# 1943.jpg
# [ 0  1  6  7  8 14 16 17 18]

# %%
ls
# Out:
# 6.jpg                face_detect.py  model.py            res/
# adpst/               hair.png        modules/            resnet.py
# CinqueSlavery.ipynb  LICENSE         optimizer.py        test.py
# cropped/             logger.py       other/              train.py
# data/                loss.py         prepropess_data.py  transform.py
# evaluate.py          makeup/         __pycache__/
# face_dataset.py      makeup.py       README.md

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 
#/content/drive/MyDrive/cvision/LOTR-Face-style-transfer/adpst/style_transfer.py
# !python style_transfer.py "--content_image" /content/drive/MyDrive/cvision/LOTR-Face-style-transfer/data/1943.jpg "--style_image" /content/drive/MyDrive/cvision/LOTR-Face-style-transfer/data/orc0.jpg
# Out:
# 2021-01-31 18:36:40.471334: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-01-31 18:36:42.222603: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-31 18:36:42.223575: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-31 18:36:42.255480: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 
#/content/drive/MyDrive/cvision/LOTR-Face-style-transfer/adpst/style_transfer.py
# !python Complete_scripts.py "--content_image" /content/drive/MyDrive/cvision/LOTR-Face-style-transfer/data/content.jpg "--style_image" /content/drive/MyDrive/cvision/LOTR-Face-style-transfer/data/orc0.jpg
# Out:
# 2021-01-31 11:42:34.714571: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-01-31 11:42:36.443560: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-31 11:42:36.444498: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-31 11:42:36.477156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python face_detect.py
#/content/drive/MyDrive/Data_LOTR/Gandalf/1943.jpg
# Out:
# 2021-01-31 18:11:44.961601: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-31 18:11:46.506790: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-31 18:11:46.516785: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-31 18:11:46.553099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-31 18:11:46.553680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !python test.py
# Out:
# [ 0  1  2  4  5  7  8 10 12 13 14 16 17]
# [ 0  1  2  3  4  5 10 11 12 13 14 17]
# [ 0  1  2  4  5  7  8 10 12 13 14 16 17]
# [ 0  1  3  6 10 11 12 13 14]
# [ 0  1  7  8 11 13 16]
# [ 0  1  3  5 10 12 13 14 16 17]
# [ 0  1  3  6 10 11 12 13 14 16]

# %%
#x=231 , y=76 , w = 121, h =157
#x=229, y=74, w=234, h=331
import cv2 
from google.colab.patches import cv2_imshow
# %matplotlib inline
content_image = cv2.imread('data/1943.jpg')
cropped_image = cv2.imread('/content/drive/MyDrive/cvision/LOTR-Face-style-transfer/result_2021_01_31_18_16/final_transfer_image.png')

w =66
h = 87
l = max(w,h)
x = 374
y = 58
start_y = max(0,y-int(0.4*l) )
start_x = x-int(0.4*l)
cropped_image = cv2.resize(cropped_image, (138,138))
content_image[start_y: start_y+ cropped_image.shape[0], start_x: start_x +  cropped_image.shape[1] ] = cropped_image
cv2_imshow(content_image)
# Out:
# <PIL.Image.Image image mode=RGB size=960x404 at 0x7F716C28A978>

# %%
# !pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3MB 17.7MB/s
# ...

# %%
# !pip install tensorpack

# %%
# !pip install sematch

# %%
import nltk
nltk.download('wordnet_ic')
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]   Package wordnet_ic is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True
